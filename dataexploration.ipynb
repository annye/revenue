# %% [markdown]
# Swimming before jumping into the water.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('Data.csv')

# %%
df.columns
# Out:
# Index([u'Client ID', u'Product', u'Revenue', u'Premium', u'Time', u'Industry',
#        u'Office_Category'],
#       dtype='object')

# %%
# Analysing Revenue

# %%
df['Revenue'].describe()
# Out:
# count     1845.000000
# mean      6188.918022
# std      10376.054822
# min         14.250000
# 25%        636.500000
# 50%       2287.000000
# 75%       7133.250000
# max      96178.000000
# Name: Revenue, dtype: float64

# %%
#Histogram

# %%
sns.distplot(df['Revenue']);

# %%
print('Skewness: %f' % df['Revenue'].skew())
print('Kurtosis: %f' % df['Revenue'].kurt())
# Out:
# Skewness: 3.491194
# Kurtosis: 16.056086

# %%
# Relationship Revenue with Numerical columns

# %%
var = 'Time'
data = pd.concat([df['Revenue'], df[var]], axis=1)
data.plot.scatter(x=var, y= 'Revenue', ylim=(0,80000));

# %%
var = 'Premium'
data = pd.concat([df['Revenue'], df[var]], axis=1)
data.plot.scatter(x=var, y= 'Revenue', ylim=(0,80000));

# %%
del df['Client ID']

# %%
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'Revenue')['Revenue'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
# histogram and normal probability plot 

sns.distplot(df['Revenue'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['Revenue'], plot=plt)

# %%
#transforming to a normal distribution

df['Revenue'] = np.log(df['Revenue'])


sns.distplot(df['Revenue'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['Revenue'], plot=plt)

# %%
# Normal distribution Premiun

# %%
sns.distplot(df['Premium'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['Premium'], plot=plt)

# %%
#transforming to a normal distribution

df['Premium'] = np.log(df['Premium'])


sns.distplot(df['Premium'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['Premium'], plot=plt)
